# %%
                  #WEB CRAWLING AND WEB SCRAPING 
          #PROJECT BY NILAVINI B.M 21PD22 & VARSHA S 21PD39


#modules that we have used
import requests as req
import urllib.request
from urllib.request import urljoin
from bs4 import BeautifulSoup
import requests
from urllib.request import urlparse
  
#queue ADT

class Queue(object):

  def _init_(self,size):
    self.queue=[]
    self.size=size

  def _str_(self):
    mystring = ' '.join(str(i) for i in self.queue)
    return mystring

  def enqueue(self,data):
    if(self.isfull()!=True):
      self.queue.append(data)
    else:
      print('Queue is FULL')

  def dequeue(self):
     if(self.isempty()!= True):
       return self.queue.pop(0)
     else:
       print('Queue is EMPTY')

  def isempty(self):
    return self.queue==[]

  def isfull(self):
    return len(self.queue)==self.size

  def front_data(self):
    if(self.isempty()!=True):
       return self.queue[0]
    else:
        print("Queue is EMPTY") 


# It is the list for storing urls with same domain 
links_intern = []

input_url = input("Enter the url : ") #the url we give
key=input("Enter your topic : ") #the topic we want to search in that website
depth = 1
  
# It is the list for storing urls with different domain
links_extern = []
suggested_url = []  #list to get the suggested urls from the given key


# Method for crawling a url at next level

#WEB CRAWLING

def web_crawler(input_url):
    
    temp_urls = [] 
    current_url_domain = urlparse(input_url).netloc
  
    # to extract html tags from the obj

    reqs=requests.get(input_url)
    b_soup= BeautifulSoup(reqs.content,"html.parser" )

    #crawling and segregating to input and output
    print("\n\n")
    print("-----------------------------------------------------------------------------------------------")
    print("-----------------------------------------CRAWLED WEB PAGES-------------------------------------")
    print(" -----------------------INTERNAL AND EXTERNAL URLS OF THE MAIN WEBSITE-------------------------")
    print("-----------------------------------------------------------------------------------------------")
    print("\n\n")

    for link in b_soup.findAll("a"):
        href = link.attrs.get("href")
        if(href != "" or href != None):
            href = urljoin(input_url, href)
            href_parsed = urlparse(href)
            href = href_parsed.scheme
            href += "://"
            href += href_parsed.netloc #from the location
            href += href_parsed.path
            final_parsed_href = urlparse(href)
            is_valid = bool(final_parsed_href.scheme) and bool(final_parsed_href.netloc)
            
            #condition 
            if is_valid:
                if current_url_domain not in href and href not in links_extern:
                    print("External - {}".format(href))
                    links_extern.append(href)
                if current_url_domain in href and href not in links_intern:
                    print("Internal - {}".format(href))
                    links_intern.append(href)
                    temp_urls.append(href)
                    if href.find(key)!=-1:
                        suggested_url.append(href)
    return temp_urls
  
  
if(depth == 1):
    web_crawler(input_url)
  
else:
    #breadth first search (bfs) method
    myqueue=Queue(1000)
    myqueue.enqueue(input_url)
    for j in range(depth):
        for count in range(len(myqueue)):
            url = myqueue.dequeue
            urls = web_crawler(url)
            for i in urls:
                myqueue.enqueue(i)
print("\n\n\n\n\n")
print("-------------------------------------------------------")
print("      SUGGESTED WEBPAGES FROM THE SAME DOMAIN")
print("-------------------------------------------------------")
print("\n\n\n")
for i in suggested_url:
  print(i)


#WEB SCRAPING 


req=requests.get(input("Enter the URL :"))
soup= BeautifulSoup(req.content,"html.parser" )

page_title=soup.title
tit= page_title.get_text()
print("\n\n")
print("---------------------------------------------------------------------------")
print("THE TITLE OF THE WEB PAGE IS :")
print("---------------------------------------------------------------------------")
print(tit)
print("---------------------------------------------------------------------------")
print("\n\n")


print("\n\n")
print("THE CONTENTS OF THE WEB PAGE IS :")
print("---------------------------------------------------------------------------")
content_page=soup.find_all('h2')
for course in content_page:
  print(course.text)
print("---------------------------------------------------------------------------")
print("\n\n")


print("\n\n")
print("THE MAIN CONTENTS OF THE GIVEN URL IS :")
print("---------------------------------------------------------------------------")
main_content_page=soup.find_all('h3')
for coursee in main_content_page:
  print(coursee.text)
print("---------------------------------------------------------------------------")
print("\n\n")
# Out:
# Enter the url : https://www.javatpoint.com/data-structure-tutorial
# Enter your topic : tree
#
#
#
# -----------------------------------------------------------------------------------------------
# -----------------------------------------CRAWLED WEB PAGES-------------------------------------
#  -----------------------INTERNAL AND EXTERNAL URLS OF THE MAIN WEBSITE-------------------------
# -----------------------------------------------------------------------------------------------
#
#
#
# Internal - https://www.javatpoint.com
# Internal - https://www.javatpoint.com/data-structure-tutorial
# Internal - https://www.javatpoint.com/c-programming-language-tutorial
# Internal - https://www.javatpoint.com/cpp-tutorial
# Internal - https://www.javatpoint.com/c-sharp-tutorial
# Internal - https://www.javatpoint.com/java-tutorial
# Internal - https://www.javatpoint.com/sql-tutorial
# Internal - https://www.javatpoint.com/html-tutorial
# Internal - https://www.javatpoint.com/css-tutorial
# Internal - https://www.javatpoint.com/javascript-tutorial
# Internal - https://www.javatpoint.com/ajax-tutorial
# Internal - https://www.javatpoint.com/android-tutorial
# Internal - https://www.javatpoint.com/cloud-computing-tutorial
# Internal - https://www.javatpoint.com/design-patterns-in-java
# Internal - https://www.javatpoint.com/examaccess
# Internal - https://www.javatpoint.com/free-java-projects
# Internal - https://www.javatpoint.com/corejava-interview-questions
# Internal - https://www.javatpoint.com/comment.jsp
# Internal - https://www.javatpoint.com/forum
# Internal - https://www.javatpoint.com/data-structure-introduction
# Internal - https://www.javatpoint.com/data-structure-algorithm
# Internal - https://www.javatpoint.com/data-structure-asymptotic-analysis
# Internal - https://www.javatpoint.com/data-structure-pointer
# Internal - https://www.javatpoint.com/data-structure-structure
# Internal - https://www.javatpoint.com/data-structure-array
# Internal - https://www.javatpoint.com/data-structure-2d-array
# Internal - https://www.javatpoint.com/ds-linked-list
# Internal - https://www.javatpoint.com/ds-types-of-linked-list
# Internal - https://www.javatpoint.com/singly-linked-list
# Internal - https://www.javatpoint.com/doubly-linked-list
# Internal - https://www.javatpoint.com/circular-singly-linked-list
# Internal - https://www.javatpoint.com/circular-doubly-linked-list
# Internal - https://www.javatpoint.com/skip-list-in-data-structure
# Internal - https://www.javatpoint.com/data-structure-stack
# Internal - https://www.javatpoint.com/ds-array-implementation-of-stack
# Internal - https://www.javatpoint.com/ds-linked-list-implementation-of-stack
# Internal - https://www.javatpoint.com/data-structure-queue
# Internal - https://www.javatpoint.com/ds-types-of-queues
# Internal - https://www.javatpoint.com/array-representation-of-queue
# Internal - https://www.javatpoint.com/linked-list-implementation-of-queue
# Internal - https://www.javatpoint.com/circular-queue
# Internal - https://www.javatpoint.com/ds-deque
# Internal - https://www.javatpoint.com/ds-priority-queue
# Internal - https://www.javatpoint.com/tree
# Internal - https://www.javatpoint.com/binary-tree
# Internal - https://www.javatpoint.com/binary-search-tree
# Internal - https://www.javatpoint.com/avl-tree
# Internal - https://www.javatpoint.com/b-tree
# Internal - https://www.javatpoint.com/b-plus-tree
# Internal - https://www.javatpoint.com/ds-graph
# Internal - https://www.javatpoint.com/graph-representation
# Internal - https://www.javatpoint.com/breadth-first-search-algorithm
# Internal - https://www.javatpoint.com/depth-first-search-algorithm
# Internal - https://www.javatpoint.com/spanning-tree
# Internal - https://www.javatpoint.com/linear-search
# Internal - https://www.javatpoint.com/binary-search
# Internal - https://www.javatpoint.com/bubble-sort
# Internal - https://www.javatpoint.com/bucket-sort
# Internal - https://www.javatpoint.com/comb-sort
# Internal - https://www.javatpoint.com/counting-sort
# Internal - https://www.javatpoint.com/heap-sort
# Internal - https://www.javatpoint.com/insertion-sort
# Internal - https://www.javatpoint.com/merge-sort
# Internal - https://www.javatpoint.com/quick-sort
# Internal - https://www.javatpoint.com/radix-sort
# Internal - https://www.javatpoint.com/selection-sort
# Internal - https://www.javatpoint.com/shell-sort
# Internal - https://www.javatpoint.com/bitonic-sort
# Internal - https://www.javatpoint.com/cocktail-sort
# Internal - https://www.javatpoint.com/cycle-sort
# Internal - https://www.javatpoint.com/tim-sort
# Internal - https://www.javatpoint.com/linear-vs-non-linear-data-structure
# Internal - https://www.javatpoint.com/ds-array-vs-linked-list
# Internal - https://www.javatpoint.com/ds-stack-vs-queue
# Internal - https://www.javatpoint.com/ds-linear-vs-circular-queue
# Internal - https://www.javatpoint.com/ds-linear-search-vs-binary-search
# Internal - https://www.javatpoint.com/singly-linked-list-vs-doubly-linked-list
# Internal - https://www.javatpoint.com/binary-tree-vs-binary-search-tree
# Internal - https://www.javatpoint.com/tree-vs-graph-data-structure
# Internal - https://www.javatpoint.com/binary-search-tree-vs-avl-tree
# Internal - https://www.javatpoint.com/red-black-tree-vs-avl-tree
# Internal - https://www.javatpoint.com/b-tree-vs-bplus-tree
# Internal - https://www.javatpoint.com/quick-sort-vs-merge-sort
# Internal - https://www.javatpoint.com/bfs-vs-dfs
# Internal - https://www.javatpoint.com/stack-vs-heap
# Internal - https://www.javatpoint.com/bubble-sort-vs-selection-sort
# Internal - https://www.javatpoint.com/ds-stack-vs-array
# Internal - https://www.javatpoint.com/full-binary-tree-vs-complete-binary-tree
# Internal - https://www.javatpoint.com/binary-tree-vs-b-tree
# Internal - https://www.javatpoint.com/primitive-vs-non-primitive-data-structure
# Internal - https://www.javatpoint.com/data-types-vs-data-structure
# Internal - https://www.javatpoint.com/trie-data-structure
# Internal - https://www.javatpoint.com/heap-data-structure
# Internal - https://www.javatpoint.com/splay-tree
# Internal - https://www.javatpoint.com/fundamental-of-the-data-structure
# Internal - https://www.javatpoint.com/hash-table
# Internal - https://www.javatpoint.com/preorder-traversal
# Internal - https://www.javatpoint.com/tree-traversal
# Internal - https://www.javatpoint.com/implementation-of-queue-using-stacks
# Internal - https://www.javatpoint.com/implementation-of-stack-using-queue
# Internal - https://www.javatpoint.com/binomial-heap
# Internal - https://www.javatpoint.com/postorder-traversal
# Internal - https://www.javatpoint.com/sparse-matrix
# Internal - https://www.javatpoint.com/detect-loop-in-a-linked-list
# Internal - https://www.javatpoint.com/inorder-traversal
# Internal - https://www.javatpoint.com/convert-infix-to-postfix-notation
# Internal - https://www.javatpoint.com/convert-infix-to-prefix-notation
# Internal - https://www.javatpoint.com/conversion-of-prefix-to-postfix-expression
# Internal - https://www.javatpoint.com/conversion-of-postfix-to-prefix-expression
# Internal - https://www.javatpoint.com/remove-loop-in-a-linked-list
# Internal - https://www.javatpoint.com/implement-two-stacks-in-an-array
# Internal - https://www.javatpoint.com/reverse-a-stack-using-recursion
# Internal - https://www.javatpoint.com/detect-cycle-in-a-directed-graph
# Internal - https://www.javatpoint.com/optimal-binary-search-tree
# Internal - https://www.javatpoint.com/priority-queue-using-linked-list
# Internal - https://www.javatpoint.com/balanced-binary-search-tree
# Internal - https://www.javatpoint.com/boundary-traversal-of-binary-tree
# Internal - https://www.javatpoint.com/diagonal-traversal-of-binary-tree
# Internal - https://www.javatpoint.com/vertical-traversal-of-a-binary-tree
# Internal - https://www.javatpoint.com/graph-algorithms
# Internal - https://www.javatpoint.com/time-complexity-of-sorting-algorithms
# Internal - https://www.javatpoint.com/applications-of-stack-in-data-structure
# Internal - https://www.javatpoint.com/dictionary-data-structure
# Internal - https://www.javatpoint.com/structured-data-and-unstructured-data
# Internal - https://www.javatpoint.com/list-data-structure
# Internal - https://www.javatpoint.com/types-of-tree-in-data-structure
# Internal - https://www.javatpoint.com/abstract-data-type-in-data-structure
# Internal - https://www.javatpoint.com/disjoint-set-data-structure
# Internal - https://www.javatpoint.com/dynamic-data-structure
# Internal - https://www.javatpoint.com/hash-function-in-data-structure
# Internal - https://www.javatpoint.com/complete-binary-tree
# Internal - https://www.javatpoint.com/threaded-binary-tree
# Internal - https://www.javatpoint.com/diameter-of-binary-tree
# Internal - https://www.javatpoint.com/height-of-binary-tree
# Internal - https://www.javatpoint.com/inorder-tree-traversal-without-stack
# Internal - https://www.javatpoint.com/enumeration-of-binary-trees
# Internal - https://www.javatpoint.com/maximum-width-of-a-binary-tree
# Internal - https://www.javatpoint.com/types-of-graph-in-data-structure
# Internal - https://www.javatpoint.com/primitive-data-type
# Internal - https://www.javatpoint.com/semi-structured-data
# Internal - https://www.javatpoint.com/advance-data-structures
# Internal - https://www.javatpoint.com/sort-an-array-of-0s-1s-and-2s
# Internal - https://www.javatpoint.com/stock-span-problem
# Internal - https://www.javatpoint.com/implementation-of-deque-by-circular-array
# Internal - https://www.javatpoint.com/rotate-operation-in-linked-list
# Internal - https://www.javatpoint.com/subarray-with-given-sum
# Internal - https://www.javatpoint.com/self-organizing-list
# Internal - https://www.javatpoint.com/unrolled-linked-list
# Internal - https://www.javatpoint.com/types-of-sparse-matrices
# Internal - https://www.javatpoint.com/application-of-linked-list
# Internal - https://www.javatpoint.com/topological-sorting
# Internal - https://www.javatpoint.com/ternary-search-tree
# Internal - https://www.javatpoint.com/treap-data-structure
# Internal - https://www.javatpoint.com/quicksort-on-doubly-linked-list
# Internal - https://www.javatpoint.com/inversion-count
# Internal - https://www.javatpoint.com/expression-tree-in-data-structure
# Internal - https://www.javatpoint.com/garbage-collection-in-data-structure
# Internal - https://www.javatpoint.com/merge-sort-on-doubly-linked-list
# Internal - https://www.javatpoint.com/sort-stack-using-recursion
# Internal - https://www.javatpoint.com/lifo-approach-in-data-structure
# Internal - https://www.javatpoint.com/big-O-notation-in-data-structure
# Internal - https://www.javatpoint.com/binary-tree-traversal-in-data-structure
# Internal - https://www.javatpoint.com/queue-operations-in-data-structure
# Internal - https://www.javatpoint.com/what-is-a-non-linear-data-structure
# Internal - https://www.javatpoint.com/fifo-approach-in-data-structure
# Internal - https://www.javatpoint.com/what-are-connected-graphs-in-data-structure
# Internal - https://www.javatpoint.com/which-python-data-structure-is-immutable
# Internal - https://www.javatpoint.com/which-data-structure-is-used-by-map
# Internal - https://www.javatpoint.com/what-is-iteration-in-data-structure
# Internal - https://www.javatpoint.com/what-are-linear-search-and-binary-search-in-data-structure
# Internal - https://www.javatpoint.com/data-structure-mcq
# Internal - https://www.javatpoint.com/advanced-data-structure-mcq
# Internal - https://www.javatpoint.com/insertion-in-singly-linked-list-at-beginning
# Internal - https://www.javatpoint.com/insertion-in-singly-linked-list-at-end
# Internal - https://www.javatpoint.com/insertion-in-singly-linked-list-after-specified-node
# Internal - https://www.javatpoint.com/deletion-in-singly-linked-list-at-beginning
# Internal - https://www.javatpoint.com/deletion-in-singly-linked-list-at-end
# Internal - https://www.javatpoint.com/deletion-in-singly-linked-list-after-specified-node
# Internal - https://www.javatpoint.com/traversing-in-singly-linked-list
# Internal - https://www.javatpoint.com/searching-in-singly-linked-list
# Internal - https://www.javatpoint.com/insertion-in-doubly-linked-list-at-beginning
# Internal - https://www.javatpoint.com/insertion-in-doubly-linked-list-at-the-end
# Internal - https://www.javatpoint.com/insertion-in-doubly-linked-list-after-specified-node
# Internal - https://www.javatpoint.com/deletion-in-doubly-linked-list-at-beginning
# Internal - https://www.javatpoint.com/deletion-in-doubly-linked-list-at-the-end
# Internal - https://www.javatpoint.com/deletion-in-doubly-linked-list-after-the-specified-node
# Internal - https://www.javatpoint.com/traversing-in-doubly-linked-list
# Internal - https://www.javatpoint.com/searching-in-doubly-linked-list
# Internal - https://www.javatpoint.com/insertion-in-circular-singly-list-at-beginning
# Internal - https://www.javatpoint.com/insertion-in-circular-singly-linked-list-at-end
# Internal - https://www.javatpoint.com/deletion-in-circular-singly-linked-list-at-beginning
# Internal - https://www.javatpoint.com/deletion-in-circular-singly-linked-list-at-end
# Internal - https://www.javatpoint.com/insertion-in-circular-doubly-linked-list-at-beginning
# Internal - https://www.javatpoint.com/insertion-in-circular-doubly-linked-list-at-end
# Internal - https://www.javatpoint.com/deletion-in-circular-doubly-linked-list-at-beginning
# Internal - https://www.javatpoint.com/deletion-in-circular-doubly-linked-list-at-end
# Internal - https://www.javatpoint.com/binary-tree-preorder-traversal
# Internal - https://www.javatpoint.com/binary-tree-inorder-traversal
# Internal - https://www.javatpoint.com/binary-tree-postorder-traversal
# Internal - https://www.javatpoint.com/searching-in-binary-search-tree
# Internal - https://www.javatpoint.com/insertion-in-binary-search-tree
# Internal - https://www.javatpoint.com/deletion-in-binary-search-tree
# Internal - https://www.javatpoint.com/insertion-in-avl-tree
# Internal - https://www.javatpoint.com/ll-rotation-in-avl-tree
# Internal - https://www.javatpoint.com/lr-rotation-in-avl-tree
# Internal - https://www.javatpoint.com/rl-rotation-in-avl-tree
# Internal - https://www.javatpoint.com/rr-rotation-in-avl-tree
# Internal - https://www.javatpoint.com/deletion-in-avl-tree
# Internal - https://www.javatpoint.com/red-black-tree
# Internal - https://www.javatpoint.com/prim-algorithm
# Internal - https://www.javatpoint.com/kruskal-algorithm
# Internal - https://www.javatpoint.com/data-structure-interview-questions
# Internal - https://www.javatpoint.com/program-to-create-and-display-a-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-create-a-singly-linked-list-of-n-nodes-and-count-the-number-of-nodes
# Internal - https://www.javatpoint.com/program-to-create-a-singly-linked-list-of-n-nodes-and-display-it-in-reverse-order
# Internal - https://www.javatpoint.com/program-to-delete-a-new-node-from-the-beginning-of-the-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-delete-a-new-node-from-the-middle-of-the-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-delete-a-node-from-the-end-of-the-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-determine-whether-a-singly-linked-list-is-the-palindrome
# Internal - https://www.javatpoint.com/program-to-find-the-maximum-and-minimum-value-node-from-a-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-insert-a-new-node-at-the-middle-of-the-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-insert-a-new-node-at-the-beginning-of-the-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-insert-a-new-node-at-the-end-of-the-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-remove-duplicate-elements-from-a-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-search-an-element-in-a-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-sort-the-elements-of-the-singly-linked-list
# Internal - https://www.javatpoint.com/program-to-swap-nodes-in-a-singly-linked-list-without-swapping-data
# Internal - https://www.javatpoint.com/program-to-swap-the-last-element-of-the-singly-linked-list-from-the-first-one
# Internal - https://www.javatpoint.com/program-to-convert-a-given-binary-tree-to-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-create-a-doubly-linked-list-from-a-ternary-tree
# Internal - https://www.javatpoint.com/program-to-create-a-doubly-linked-list-of-n-nodes-and-count-the-number-of-nodes
# Internal - https://www.javatpoint.com/program-to-create-a-doubly-linked-list-of-n-nodes-and-display-it-in-reverse-order
# Internal - https://www.javatpoint.com/program-to-create-and-display-a-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-delete-a-new-node-from-the-beginning-of-the-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-delete-a-new-node-from-the-end-of-the-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-delete-a-new-node-from-the-middle-of-the-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-find-the-maximum-and-minimum-value-node-from-a-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-insert-a-new-node-at-the-beginning-of-the-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-insert-a-new-node-at-the-end-of-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-insert-a-new-node-at-the-middle-of-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-remove-duplicate-elements-from-a-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-rotate-doubly-linked-list-by-n-nodes
# Internal - https://www.javatpoint.com/program-to-search-an-element-in-a-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-sort-the-elements-of-the-doubly-linked-list
# Internal - https://www.javatpoint.com/program-to-create-a-circular-linked-list-of-n-nodes-and-count-the-number-of-nodes
# Internal - https://www.javatpoint.com/program-to-create-a-circular-linked-list-of-n-nodes-and-display-it-in-reverse-order
# Internal - https://www.javatpoint.com/program-to-create-and-display-a-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-delete-a-new-node-from-the-beginning-of-the-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-delete-a-new-node-from-the-end-of-the-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-delete-a-new-node-from-the-middle-of-the-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-find-the-maximum-and-minimum-value-node-from-a-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-insert-a-new-node-at-the-beginning-of-the-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-insert-a-new-node-at-the-end-of-the-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-insert-a-new-node-at-the-middle-of-the-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-remove-duplicate-elements-from-a-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-search-an-element-in-a-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-sort-the-elements-of-the-circular-linked-list
# Internal - https://www.javatpoint.com/program-to-calculate-the-difference-between-the-sum-of-the-odd-level-and-even-level-nodes-of-a-binary-tree
# Internal - https://www.javatpoint.com/program-to-construct-a-binary-search-tree-and-perform-deletion-and-inorder-traversal
# Internal - https://www.javatpoint.com/program-to-convert-binary-tree-to-binary-search-tree
# Internal - https://www.javatpoint.com/program-to-determine-whether-all-leaves-are-at-same-level
# Internal - https://www.javatpoint.com/program-to-determine-whether-two-trees-are-identical
# Internal - https://www.javatpoint.com/program-to-find-maximum-width-of-a-binary-tree
# Internal - https://www.javatpoint.com/program-to-find-the-largest-element-in-a-binary-tree
# Internal - https://www.javatpoint.com/program-to-find-the-maximum-depth-or-height-of-a-tree
# Internal - https://www.javatpoint.com/program-to-find-the-nodes-which-are-at-the-maximum-distance-in-a-binary-tree
# Internal - https://www.javatpoint.com/program-to-find-the-smallest-element-in-a-binary-tree
# Internal - https://www.javatpoint.com/program-to-find-the-sum-of-all-the-nodes-of-a-binary-tree
# Internal - https://www.javatpoint.com/program-to-find-the-total-number-of-possible-binary-search-trees-with-n-keys
# Internal - https://www.javatpoint.com/program-to-implement-binary-tree-using-the-linked-list
# Internal - https://www.javatpoint.com/program-to-search-a-node-in-a-binary-tree
# External - https://bit.ly/2FOeX6S
# Internal - https://www.javatpoint.com/cdn-cgi/l/email-protection
# External - https://www.facebook.com/sharer.php
# External - https://twitter.com/share
# External - https://www.pinterest.com/pin/create/button/
# Internal - https://www.javatpoint.com/splunk
# Internal - https://www.javatpoint.com/spss
# Internal - https://www.javatpoint.com/swagger
# Internal - https://www.javatpoint.com/t-sql
# Internal - https://www.javatpoint.com/tumblr
# Internal - https://www.javatpoint.com/reactjs-tutorial
# Internal - https://www.javatpoint.com/regex
# Internal - https://www.javatpoint.com/reinforcement-learning
# Internal - https://www.javatpoint.com/r-tutorial
# Internal - https://www.javatpoint.com/rxjs
# Internal - https://www.javatpoint.com/react-native-tutorial
# Internal - https://www.javatpoint.com/python-design-pattern
# Internal - https://www.javatpoint.com/python-pillow
# Internal - https://www.javatpoint.com/python-turtle-programming
# Internal - https://www.javatpoint.com/keras
# Internal - https://www.javatpoint.com/aptitude/quantitative
# Internal - https://www.javatpoint.com/reasoning
# Internal - https://www.javatpoint.com/verbal-ability
# Internal - https://www.javatpoint.com/interview-questions-and-answers
# Internal - https://www.javatpoint.com/company-interview-questions-and-recruitment-process
# Internal - https://www.javatpoint.com/artificial-intelligence-tutorial
# Internal - https://www.javatpoint.com/aws-tutorial
# Internal - https://www.javatpoint.com/selenium-tutorial
# Internal - https://www.javatpoint.com/hadoop-tutorial
# Internal - https://www.javatpoint.com/data-science
# Internal - https://www.javatpoint.com/angular-7-tutorial
# Internal - https://www.javatpoint.com/blockchain-tutorial
# Internal - https://www.javatpoint.com/git
# Internal - https://www.javatpoint.com/machine-learning
# Internal - https://www.javatpoint.com/devops
# Internal - https://www.javatpoint.com/dbms-tutorial
# Internal - https://www.javatpoint.com/daa-tutorial
# Internal - https://www.javatpoint.com/os-tutorial
# Internal - https://www.javatpoint.com/computer-network-tutorial
# Internal - https://www.javatpoint.com/compiler-tutorial
# Internal - https://www.javatpoint.com/computer-organization-and-architecture-tutorial
# Internal - https://www.javatpoint.com/discrete-mathematics-tutorial
# Internal - https://www.javatpoint.com/ethical-hacking-tutorial
# Internal - https://www.javatpoint.com/computer-graphics-tutorial
# Internal - https://www.javatpoint.com/software-engineering-tutorial
# Internal - https://www.javatpoint.com/cyber-security-tutorial
# Internal - https://www.javatpoint.com/automata-tutorial
# Internal - https://www.javatpoint.com/net-framework
# Internal - https://www.javatpoint.com/python-tutorial
# Internal - https://www.javatpoint.com/programs-list
# Internal - https://www.javatpoint.com/control-system-tutorial
# Internal - https://www.javatpoint.com/data-mining
# Internal - https://www.javatpoint.com/data-warehouse
# External - https://feeds.feedburner.com/javatpointsonoo
# External - https://feedburner.google.com/fb/a/mailverify
# External - https://www.facebook.com/javatpoint
# External - https://twitter.com/pagejavatpoint
# External - https://www.youtube.com/channel/UCUnYvQVCrJoFWZhKK3O2xLg
# External - https://javatpoint.blogspot.com
# Internal - https://www.javatpoint.com/php-tutorial
# Internal - https://www.javatpoint.com/jquery-tutorial
# Internal - https://www.javatpoint.com/spring-tutorial
# External - https://www.hindi100.com
# External - https://www.lyricsia.com
# External - https://www.quoteperson.com
# External - https://www.jobandplacement.com
# Internal - https://www.javatpoint.com/contact-us
# Internal - https://www.javatpoint.com/subscribe.jsp
# Internal - https://www.javatpoint.com/privacy-policy
# Internal - https://www.javatpoint.com/sitemap.xml
# Internal - https://www.javatpoint.com/sonoo-jaiswal
#
#
#
#
#
#
# -------------------------------------------------------
#       SUGGESTED WEBPAGES FROM THE SAME DOMAIN
# -------------------------------------------------------
#
#
#
#
# https://www.javatpoint.com/tree
# https://www.javatpoint.com/binary-tree
# https://www.javatpoint.com/binary-search-tree
# https://www.javatpoint.com/avl-tree
# https://www.javatpoint.com/b-tree
# https://www.javatpoint.com/b-plus-tree
# https://www.javatpoint.com/spanning-tree
# https://www.javatpoint.com/binary-tree-vs-binary-search-tree
# https://www.javatpoint.com/tree-vs-graph-data-structure
# https://www.javatpoint.com/binary-search-tree-vs-avl-tree
# https://www.javatpoint.com/red-black-tree-vs-avl-tree
# https://www.javatpoint.com/b-tree-vs-bplus-tree
# https://www.javatpoint.com/full-binary-tree-vs-complete-binary-tree
# https://www.javatpoint.com/binary-tree-vs-b-tree
# https://www.javatpoint.com/splay-tree
# https://www.javatpoint.com/tree-traversal
# https://www.javatpoint.com/optimal-binary-search-tree
# https://www.javatpoint.com/balanced-binary-search-tree
# https://www.javatpoint.com/boundary-traversal-of-binary-tree
# https://www.javatpoint.com/diagonal-traversal-of-binary-tree
# https://www.javatpoint.com/vertical-traversal-of-a-binary-tree
# https://www.javatpoint.com/types-of-tree-in-data-structure
# https://www.javatpoint.com/complete-binary-tree
# https://www.javatpoint.com/threaded-binary-tree
# https://www.javatpoint.com/diameter-of-binary-tree
# https://www.javatpoint.com/height-of-binary-tree
# https://www.javatpoint.com/inorder-tree-traversal-without-stack
# https://www.javatpoint.com/enumeration-of-binary-trees
# https://www.javatpoint.com/maximum-width-of-a-binary-tree
# https://www.javatpoint.com/ternary-search-tree
# https://www.javatpoint.com/expression-tree-in-data-structure
# https://www.javatpoint.com/binary-tree-traversal-in-data-structure
# https://www.javatpoint.com/binary-tree-preorder-traversal
# https://www.javatpoint.com/binary-tree-inorder-traversal
# https://www.javatpoint.com/binary-tree-postorder-traversal
# https://www.javatpoint.com/searching-in-binary-search-tree
# https://www.javatpoint.com/insertion-in-binary-search-tree
# https://www.javatpoint.com/deletion-in-binary-search-tree
# https://www.javatpoint.com/insertion-in-avl-tree
# https://www.javatpoint.com/ll-rotation-in-avl-tree
# https://www.javatpoint.com/lr-rotation-in-avl-tree
# https://www.javatpoint.com/rl-rotation-in-avl-tree
# https://www.javatpoint.com/rr-rotation-in-avl-tree
# https://www.javatpoint.com/deletion-in-avl-tree
# https://www.javatpoint.com/red-black-tree
# https://www.javatpoint.com/program-to-convert-a-given-binary-tree-to-doubly-linked-list
# https://www.javatpoint.com/program-to-create-a-doubly-linked-list-from-a-ternary-tree
# https://www.javatpoint.com/program-to-calculate-the-difference-between-the-sum-of-the-odd-level-and-even-level-nodes-of-a-binary-tree
# https://www.javatpoint.com/program-to-construct-a-binary-search-tree-and-perform-deletion-and-inorder-traversal
# https://www.javatpoint.com/program-to-convert-binary-tree-to-binary-search-tree
# https://www.javatpoint.com/program-to-determine-whether-two-trees-are-identical
# https://www.javatpoint.com/program-to-find-maximum-width-of-a-binary-tree
# https://www.javatpoint.com/program-to-find-the-largest-element-in-a-binary-tree
# https://www.javatpoint.com/program-to-find-the-maximum-depth-or-height-of-a-tree
# https://www.javatpoint.com/program-to-find-the-nodes-which-are-at-the-maximum-distance-in-a-binary-tree
# https://www.javatpoint.com/program-to-find-the-smallest-element-in-a-binary-tree
# https://www.javatpoint.com/program-to-find-the-sum-of-all-the-nodes-of-a-binary-tree
# https://www.javatpoint.com/program-to-find-the-total-number-of-possible-binary-search-trees-with-n-keys
# https://www.javatpoint.com/program-to-implement-binary-tree-using-the-linked-list
# https://www.javatpoint.com/program-to-search-a-node-in-a-binary-tree
# Enter the URL :https://www.javatpoint.com/data-structure-tutorial
#
#
#
# ---------------------------------------------------------------------------
# THE TITLE OF THE WEB PAGE IS :
# ---------------------------------------------------------------------------
# Data Structures | DS Tutorial - javatpoint
# ---------------------------------------------------------------------------
#
#
#
#
#
#
# THE CONTENTS OF THE WEB PAGE IS :
# ---------------------------------------------------------------------------
# DS Tutorial
# DS Array
# DS Linked List
# DS Stack
# DS Queue
# DS Tree
# DS Graph
# DS Searching
# DS Sorting
# Differences
# Misc
# DS MCQ
# Data Structures Index
# Prerequisite
# Audience
# Problem
# Help Others, Please Share
# Learn Latest Tutorials
# Preparation
# Trending Technologies
# B.Tech / MCA
# Javatpoint Services
# Training For College Campus
# ---------------------------------------------------------------------------
#
#
#
#
#
#
# THE MAIN CONTENTS OF THE GIVEN URL IS :
# ---------------------------------------------------------------------------
# What is Data Structure?
# Types of Data Structures
# Major Operations
# Which Data Structure?
# Advantages of Data structures
# Feedback
# Learn Tutorials
# Our Websites
# Our Services
# Contact
# ---------------------------------------------------------------------------
